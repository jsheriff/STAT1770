# %% [markdown]
# # Lab 9 Assignment
#
# #### Lab 9 Assignment is due on Sunday, November 30, at 8:00 pm.
#
# #### Complete this notebook, by introducing and executing the required code and answering the related questions.
#
# #### When you have finished your work and wish to submit your assignment, download this notebook as a pdf file File > Save and Export Notebook as > PDF or File > Print > Save as PDF.  Submit the pdf file to Lab 9 Assignment in Crowdmark.
#
# #### You can copy, paste, and modify code from previous labs if you wish, as opposed to writing code from scratch. Open the previous lab and highlight the code you want. Then copy and paste the code into this assignment and make the necessary modifications.
#
# #### If you have questions, please ask.
#
# ---

# %% [markdown]
# ## Reminder - working with notebooks
#
# #### 1) It is important to save your work, exit the notebook, and logout of syzygy whenever you are finished working on the notebook for that session.
#
# - **Select File > Save Notebook or select the Save icon above to save your work.**
# - **To exit the notebook, select File > Close and Shutdown Notebook.**
# - **Select File > Log Out.**
#
#
# #### 2) When you resume your work on a notebook, your previous work/output may still be displayed, but none of your previous work is maintained in memory accessible by the notebook. In particular, you will need to load the dataset again in order to continue working with the data. One easy way to refresh your notebook is to go to the notebook cell where you left off and do the following.
#
# - **Select Kernel > Restart Kernel and Run up to Selected Cell.**
# #### This will run all of the code in your notebook up to the selected cell.

# %% [markdown]
# ## Sleep Deprivation
#
# November 2-8, 2025 was the National Sleep Foundation's Drowsy Driving Prevention Week in the United States. This week encourages people to prioritize sleep and drive when they are alert and refreshed. The National Sleep Foundation also sponsors an annual Sleep in America Survey that is a review of current sleep topics. In this assignment we will explore Sleep in America Survey results that focus on sleep habits of transportation workers. The dataset represents a random sample of 1087 subjects.
#
# ---

# %% [markdown]
# ## Data Information:
#
# ### Data Set:
#
# #### Name: ####
# * `sleep_deprivation`
#
#
# #### Variables: ####
#
# The variables included in the dataset are
#
# * `sleep`: a factor with levels `<6`, `6-8`, and `>8`
# * `profession`: a factor with levels `bus / taxi / limo drivers`, `control`, `pilots`, `train operators`, `truck drivers`

# %% [markdown]
# ## Load Data:

# %%
download.file("http://www.openintro.org/data/rda/sleep_deprivation.rda",destfile = "sleep_deprivation.rda")
load("sleep_deprivation.rda")

# %% [markdown]
# The `download.file` function and `load` function are used to import the dataset that will be used in the assignment. The data that is available to you is called `sleep_deprivation`. These commands instruct R to access the OpenIntro website and retrieve some data, which is in a file called `sleep_deprivation.rda`. The .rda indicates a file format, like .csv, .txt etc. R is capable of importing files of various formats (using the appropriate command). The `sleep_deprivation` dataset, which is contained within `sleep_deprivation.rda` is already in a format native to R.

# %% [markdown]
# We could use some combination of `head`, `tail`, `dim`, `names`, `str` to begin exploring the `sleep_deprivation` dataset.

# %%
head(sleep_deprivation)

# %% [markdown]
# #### Exercise 1:  Construct a table that displays the count of respondents in the sample that fall into each sleep category: `<6`, `6-8`, `>8`. That is a table of counts for the variable `sleep`. (2 marks)

# %% [markdown]
# #### Exercise 2:  Construct a table that displays the proportion of respondents in the sample that that fall into each sleep category: `<6`, `6-8`, `>8`. That is a table of proportions for the variable `sleep`. (2 marks)

# %% [markdown]
# #### Exercise 3:  Create a barplot that displays the proportions of respondents in the sample that fall into each sleep category: `<6`, `6-8`, `>8`. (2 marks)

# %% [markdown]
# #### Exercise 4:  What proportion of respondents in the sample get more than 8 hours of sleep? (1 mark)

# %% [markdown]
# #### Answer:

# %% [markdown]
# #### Central Limit Theorem conditions <br><br> Independence: We have a random sample of transportation workers and the sample is not more than 10% of the population <br><br> Sample size large enough: <br><br> * Success: For either the hypothesis test or the confidence interval you can show that either $np_0 \ge 10$ or $n\hat{p} \ge 10$  <br> <br> * Failure: For either the hypothesis test or the confidence interval you can show that either $n(1-\hat{p}) \ge 10$ or $n(1-\hat{p}) \ge 10$  <br><br> Therefore, the CLT conditions are satisfied in this case.

# %% [markdown]
# #### Exercise 5:  Suppose that previous studies suggested that approximately 25%, of transportation workers get more than 8 hours of sleep, but researchers are concerned that the proportion has decreased. Use the `prop.test` function to conduct a hypothesis test for the hypothesis that the proportion of transportation workers getting more than 8 hours of sleep (`>8`) is less than 0.25.  (2 marks)

# %% [markdown]
# #### Exercise 6:  Report the value of the test statistic and the p-value associated with the test (2 marks)

# %% [markdown]
# #### Answer:

# %% [markdown]
# #### Exercise 7:  Briefly explain whether there is evidence that less than 66.7% of all transportation workers are getting more than 8 hours of sleep? (You may use a 0.05 significance level, $\alpha = 0.05$. (2 marks)

# %% [markdown]
# #### Answer:

# %% [markdown]
# #### Exercise 8:  According to the National Sleep Foundation, individuals who have had too little sleep Use the `prop.test` function to construct a 95% confidence interval for the proportion of all transportation workers that get less than 6 hours of sleep (`<6`). (2 marks)

# %% [markdown]
# #### Exercise 9:  Interpret the confidence interval for the proportion of transportation workers that get less than 6 hours of sleep. (2 marks)

# %% [markdown]
# #### Answer:

# %% [markdown]
# - **When you have finished your work and wish to submit your lab, you need to download this notebook as a pdf file. There are two common ways to do this.**
# 1) **File > Save and Export Notebook As > PDF.**
# 2) **File > Print > Save As PDF.**
# - **Submit the pdf file to Lab 9 in Crowdmark.**
#
#
# #### It is important to save your work, exit the notebook, and logout of syzygy when you are done.
#
# - **Select File > Save Notebook or select the Save icon above to save your work.**
# - **To exit the notebook, select File > Close and Shutdown Notebook.**
# - **Select File > Log Out.**
